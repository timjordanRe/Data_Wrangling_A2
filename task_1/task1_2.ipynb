# %% [markdown]
# ## 1.2 Imputating data

# %%
import pandas as pd

# %%
clean_df = pd.read_csv('output/Group109_dirty_data_solution.csv')

# %%
missing_path = "data/Group109_missing_data.csv"
missing_df = pd.read_csv(missing_path)

# %%
def check_missing_data_for_delivery_fee(row):
    print(row['delivery_fee'])
    res = 0
    if row['delivery_fee']:
        res = row.isna().sum(axis = 1)
    return res

# %%
missing_df
# Out:
#       order_id        date      time order_type branch_code  \
# 0    ORDI00701  2018-11-30  18:59:09     Dinner         NaN
# 1    ORDK02739  2018-09-27  16:57:27     Dinner          BK
# 2    ORDY00350  2018-10-31  17:58:18     Dinner         NaN
# 3    ORDA10679  2018-10-25  17:48:10     Dinner          BK
# 4    ORDA09570  2018-01-25  08:40:33  Breakfast          BK
# ..         ...         ...       ...        ...         ...
# 495  ORDK00818  2018-05-13  12:23:39      Lunch          BK
# 496  ORDC08224  2018-08-12  15:26:11      Lunch          NS
# 497  ORDA09035  2018-11-08  18:18:35     Dinner          BK
# 498  ORDY09642  2018-09-01  16:06:45     Dinner          TP
# 499  ORDC02001  2018-05-29  12:54:05      Lunch          NS
#
#                                            order_items  order_price  \
# 0    [('Shrimp', 9), ('Pasta', 3), ('Fish&Chips', 7...       1100.5
# 1    [('Shrimp', 2), ('Salmon', 4), ('Fish&Chips', 2)]        342.0
# ...

# %%
missing_df[missing_df['delivery_fee'].isna()]
# Out:
#       order_id        date      time order_type branch_code  \
# 7    ORDA00394  2018-06-12  13:24:30      Lunch          BK
# 36   ORDX05963  2018-10-31  17:58:18     Dinner          BK
# 56   ORDY06728  2018-05-14  12:23:39      Lunch          TP
# 66   ORDA02839  2018-04-27  11:53:14  Breakfast          BK
# 69   ORDA04562  2018-03-30  10:52:23  Breakfast          BK
# 73   ORDB05756  2018-09-29  16:57:27     Dinner          TP
# 80   ORDZ01920  2018-06-22  13:44:47      Lunch          NS
# 81   ORDA01813  2018-10-26  17:48:10     Dinner          BK
# 85   ORDJ01031  2018-11-13  18:28:43     Dinner          TP
# 104  ORDI07560  2018-06-18  13:34:38      Lunch          NS
# 115  ORDX01412  2018-12-01  19:09:17     Dinner          BK
# 134  ORDA03723  2018-10-30  17:58:18     Dinner          BK
# 152  ORDY02051  2018-04-10  11:12:40  Breakfast          TP
# 164  ORDA10629  2018-12-05  19:09:17     Dinner          BK
# 176  ORDZ10757  2018-08-04  15:05:54      Lunch          NS
# ...

# %%
type(missing_df.loc[0]['branch_code'])
# Out:
# float

# %%
type(missing_df.loc[0]['distance_to_customer_KM'])
# Out:
# numpy.float64

# %%
missing_df.apply(check_missing_data_for_delivery_fee, axis=1)
# Out:
# 14.7660866
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# g:\anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     459         try:
# --> 460             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     461         except KeyError:
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-f721aa015994> in <module>
# ----> 1 missing_df.apply(check_missing_data_for_delivery_fee, axis=1)
#
# g:\anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7766             kwds=kwds,
#    7767         )
# -> 7768         return op.get_result()
#    7769
#    7770     def applymap(self, func, na_action: Optional[str] = None) -> DataFrame:
#
# ...

# %%
missing_df.head()
# Out:
#     order_id        date      time order_type branch_code  \
# 0  ORDI00701  2018-11-30  18:59:09     Dinner         NaN
# 1  ORDK02739  2018-09-27  16:57:27     Dinner          BK
# 2  ORDY00350  2018-10-31  17:58:18     Dinner         NaN
# 3  ORDA10679  2018-10-25  17:48:10     Dinner          BK
# 4  ORDA09570  2018-01-25  08:40:33  Breakfast          BK
#
#                                          order_items  order_price  \
# 0  [('Shrimp', 9), ('Pasta', 3), ('Fish&Chips', 7...       1100.5
# 1  [('Shrimp', 2), ('Salmon', 4), ('Fish&Chips', 2)]        342.0
# 2  [('Fish&Chips', 4), ('Salmon', 1), ('Shrimp', 2)]        289.0
# 3  [('Fish&Chips', 10), ('Shrimp', 4), ('Salmon',...        730.0
# 4       [('Eggs', 10), ('Cereal', 9), ('Coffee', 9)]        476.5
#
#    customer_lat  customer_lon  customerHasloyalty?  distance_to_customer_KM  \
# 0    -37.802854    145.003631                    0                      NaN
# ...
